# %%
import NCrystal as NC
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas
plt.rc('font', family='serif')
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=13)

# %%
#PPF
A1=132.869
b1=1.33605
A2=0.0519763
b2=3.97314
Q0=0.0510821
corr=10

# %%
#GPF
A=66
s=1.5
rg=14.64
m=4.15
p=2.13

# %%
#HSFBA
R=2.4

# %%
version = 2.0
dummyal="""NCMAT v5
#Diamond.
#
#Crystal structure was converted from the cif file of the entry 0011242 in the AMCSD.
#Additional reference: Wyckoff R W G, Crystal Structures, vol. 1, p. 7-83, 1963.
#
#The Debye temperature is derived from the Debye-waller factor at 293K compiled
#in the supplement of Acta Cryst., A52, p. 456-470, 1996
#
#The VDOS curve was extracted by T. Kittelmann using the engauge digitizer
#software from Figure 9 (the 0 GPa curve) of:
#
#   "High-pressure thermal expansion, bulk modulus, and phonon structure of diamond"
#   Jianjun Xie, et. al.
#   Phys. Rev. B 60, 9444 - Published 1 October 1999
#   https://doi.org/10.1103/PhysRevB.60.9444
#
@CELL
  lengths 3.56679 3.56679 3.56679
  angles 90 90 90
@SPACEGROUP
  227
@ATOMPOSITIONS
  C 1/2 0   1/2
  C 1/4 3/4 3/4
  C 1/2 1/2 0
  C 1/4 1/4 1/4
  C 0   0   0
  C 3/4 3/4 1/4
  C 0   1/2 1/2
  C 3/4 1/4 3/4
@DYNINFO
  element  C
  fraction 1
  type     vdos
  vdos_egrid .040474125140929 .16798283517138
  vdos_density .0208322 .0213076 .0217831 .0222585 .022734 .0232095 .0236849
    .0241604 .0246358 .0251113 .0255868 .0260622 .0265377 .0270133 .0275731
    .0281328 .0286926 .0292523 .0298121 .0303718 .0309315 .0314913 .032051
    .0326108 .0331705 .0337302 .03429 .0348497 .0356357 .0364415 .0372473
    .0380532 .038859 .0396648 .0404706 .0412765 .0420823 .0428881 .0436939
    .0444998 .0453056 .0461114 .0468834 .0476182 .0483529 .0490876 .0498223
    .0505571 .0512918 .0520265 .0527612 .053496 .0542702 .055183 .0560958
    .0570086 .0579214 .0588342 .059747 .0607879 .0619747 .0631614 .0643482
    .0655349 .0667217 .0679084 .0690952 .0703094 .0717365 .0731637 .0745908
    .0760962 .0776445 .0791928 .0807411 .0822894 .0838377 .0856917 .0878991
    .0901065 .0923139 .0945213 .0976238 .101169 .10377 .104992 .108393 .114493
    .120593 .126694 .132794 .138894 .144994 .146451 .147567 .148684 .1498
    .150917 .152033 .15315 .154137 .154192 .154247 .154301 .154356 .154411
    .154466 .154521 .154575 .15463 .154967 .155995 .157022 .158049 .159076
    .160103 .16113 .162157 .162549 .162916 .163284 .163651 .164018 .164386
    .164753 .16512 .165488 .165855 .166222 .16659 .166957 .167324 .167927
    .168808 .169689 .17057 .171451 .172331 .173212 .174069 .174612 .175156
    .175699 .176242 .176785 .177328 .177872 .178415 .178958 .179501 .180045
    .180692 .181497 .182302 .183106 .183911 .184716 .18552 .186325 .187117
    .187897 .188677 .189458 .190238 .191019 .191799 .192635 .193608 .19458
    .195553 .196525 .197498 .19847 .199443 .201077 .202782 .204487 .206103
    .207348 .208593 .209839 .211403 .214142 .216881 .218667 .220738 .223765
    .2141 .201306 .193143 .18784 .184288 .185293 .195514 .205401 .172496 .168951
    .165405 .162106 .160663 .159221 .157778 .156335 .154892 .153145 .151376
    .149607 .147838 .146924 .146116 .145307 .144498 .143689 .142477 .141042
    .139607 .138172 .136737 .135463 .134894 .134325 .133756 .133186 .132965
    .132877 .132789 .132701 .132613 .132525 .132437 .132349 .132261 .132214
    .132235 .132256 .132277 .132297 .132318 .132339 .13236 .132381 .132402
    .133474 .134617 .13576 .136934 .138717 .1405 .142283 .143533 .144639 .145746
    .146853 .14796 .149649 .153727 .148934 .142612 .139787 .13817 .138382
    .138594 .138806 .139018 .13923 .141406 .144479 .14733 .150019 .152751
    .155708 .158586 .160988 .163541 .166937 .170333 .176119 .183038 .192287
    .206496 .22562 .245836 .252412 .262008 .25854 .26291 .268142 .27071 .261951
    .24655 .221666 .209016 .205139 .201262 .197386 .191581 .185467 .180004
    .176313 .172621 .168359 .162538 .15627 .15214 .148415 .144716 .141082
    .137448 .134439 .131758 .128905 .125789 .123866 .124448 .126201 .135127
    .138293 .146204 .15248 .178646 .199596 .203163 .195408 .183744 .16916
    .162971 .159575 .162367 .165421 .171465 .180004 .192103 .203499 .213156
    .222813 .233418 .244643 .25807 .273766 .291084 .31186 .332635 .357688
    .371861 .38364 .395821 .408464 .424661 .448554 .47286 .484037 .484864
    .484827 .479981 .465302 .451224 .434788 .424912 .424257 .42579 .430239
    .434809 .441672 .449316 .455607 .46594 .479648 .501786 .5229 .541428 .562215
    .586174 .630549 .693711 .74561 .779826 .865355 .934832 1 .958397 .944071
    .944199 .95086 .97667 .841092 .74341 .64457 .486839 .405613 .382277 .357093
    .342668 .331059 .318807 .302933 .291655 .281707 .275841 .269975 .263549
    .257005 .251534 .247 .242356 .237365 .232373 .226915 .220776 .218083 .217178
    .265855 .300494 .41769 .385856 .222808 .130473 .0823366 .0292034 .0125285 0
"""

# %%
PPF='@CUSTOM_%s\n  %g\n %s\n %g %g %g %g %g %g'% ( "SANSND", 
                                        version,
                                        "PPF",
                                        A1,b1,A2,b2,Q0,corr)

GPF='@CUSTOM_%s\n  %g\n %s\n %g %g %g %g %g'% ( "SANSND", 
                                        version,
                                        "GPF",
                                        A,s,rg,m,p)

FILE='@CUSTOM_%s\n  %g\n %s\n %s'% ( "SANSND", 
                                       version,
                                       "FILE",
                                      "teshi_xs")

HSFBA='@CUSTOM_%s\n  %g\n %s\n %s'% ( "SANSND", 
                                       version,
                                        "HSFBA",
                                        2.4 )               

NC.registerInMemoryFileData('stdDiamond.ncmat', dummyal)
NC.registerInMemoryFileData('customDiamond.ncmat', dummyal+PPF)
#NC.registerInMemoryFileData('customDiamond2.ncmat', dummyal+GPF)
#NC.registerInMemoryFileData('customDiamond3.ncmat', dummyal+FILE)
NC.registerInMemoryFileData('customDiamond4.ncmat', dummyal+HSFBA)

# %%
######################################################################
#
# Create physics model with/without our custom replacement 
#
sc_std = NC.createScatter("stdDiamond.ncmat")
sc_plugin = NC.createScatter("customDiamond.ncmat")
#sc_plugin2 = NC.createScatter("customDiamond2.ncmat")
#sc_plugin3 = NC.createScatter("customDiamond3.ncmat")
sc_plugin4 = NC.createScatter("customDiamond4.ncmat")
# Out:
# NCrystal::NCMATLoader WARNING: Loading NCMAT data which has @CUSTOM_ section(s). This is OK if intended.
# Mode PPF selected

# %%
######################################################################
#
# Plot with matplotlib:
#
plt.figure(num='Benchmark',figsize=(7,5),dpi=300)
energies = np.logspace(-4,0,100000)
xs =  sc_plugin.crossSectionNonOriented(energies)
#xs2 =  sc_plugin2.crossSectionNonOriented(energies)
#xs3 =  sc_plugin3.crossSectionNonOriented(energies)
xs4 =  sc_plugin4.crossSectionNonOriented(energies)
xs_std = sc_std.crossSectionNonOriented(energies)
#plt.plot(energies, xs_std, label="NCrystal Diamond",linestyle='dashed',color="tab:red")
plt.plot(energies, xs, label="PPF", color="tab:orange")
#plt.plot(energies, xs2, label="GP", color="tab:green")
#plt.plot(energies, xs3, label="Teshi", color="tab:blue")
plt.plot(energies, xs4, label=f"HS R={R:.2f} nm", color="tab:brown")
#plt.plot(energies, xs6, label=f"Simple A={A_simple:.2f}", color="tab:cyan")
#plt.plot( wls, sc_std_incelas_only.xsect(wl=wls), label='Standard NCrystal [only inc. elas.]' )
#plt.plot( wls, sc_plugin_incelas_only.xsect(wl=wls), label='With new plugin [only inc. elas.]' )

######################################################################
teshi_data = pandas.read_csv("/home/nicorizzi/ncplugin-SANSND/testcode/data/teshi_xs.dat", sep=" ")
vesuvio_data = pandas.read_csv("/home/nicorizzi/ncplugin-SANSND/testcode/data/vesuvio.dat", sep=" ")

plt.scatter(teshi_data["E"],teshi_data["xs"], s=15, facecolors='none', edgecolors='tab:olive', label='Teshigawara at al. [2019]')
plt.scatter(vesuvio_data["E"][vesuvio_data["E"]<1],vesuvio_data["xs"][vesuvio_data["E"]<1],s=15, facecolors='none', edgecolors='tab:purple',label='VESUVIO exp. [2019]')

plt.xlabel('Energy (eV)')
plt.ylabel('Total Cross Section (barn)')
plt.legend()
#plt.grid(which='both', linestyle=':')
plt.loglog()

## RESIDUAL PLOT
plt.figure(num='Residual')
#plt.step( ekins,(sc_plugin.xsect(ekins) - sc_std.xsect(ekins))/sc_std.xsect(ekins), where='mid',lw=1,label='With SANS' )
#plt.step( teshi_data["E"], (teshi_data["xs"]-sc_plugin.xsect(wl=NC.ekin2wl(teshi_data["E"])))/sc_plugin.xsect(wl=NC.ekin2wl(teshi_data["E"])), where='mid',color='r',lw=1,label='Teshigawara et al.')
#plt.step( vesuvio_data["E"], (vesuvio_data["xs"] - sc_plugin6.xsect(wl=NC.ekin2wl(vesuvio_data["E"])))/sc_plugin6.xsect(wl=NC.ekin2wl(vesuvio_data["E"])), lw=1, color='tab:cyan', where='mid',label='simple' )
#plt.step( vesuvio_data["E"], (vesuvio_data["xs"] - sc_plugin2.xsect(wl=NC.ekin2wl(vesuvio_data["E"])))/sc_plugin2.xsect(wl=NC.ekin2wl(vesuvio_data["E"])), lw=1, color='tab:green', where='mid',label='GP' )
plt.step( vesuvio_data["E"], (vesuvio_data["xs"] - sc_plugin4.xsect(wl=NC.ekin2wl(vesuvio_data["E"])))/sc_plugin4.xsect(wl=NC.ekin2wl(vesuvio_data["E"])), lw=1, color='tab:red', where='mid',label='HSFBA' )

 
plt.xlabel('Energy (eV)')
plt.ylabel('')
plt.title('Residual Total Cross Section relative to Vesuvio Exp')
plt.legend()
plt.grid(which='both', linestyle=':')
plt.xscale('log')
plt.gca().set_xlim(right=1)


plt.show()

# %%
print("\ncross section PPF @ 0.01 ", sc_plugin.crossSectionNonOriented(0.01))
print("\ncross section GP @ 0.01 ", sc_plugin2.crossSectionNonOriented(0.01))
print("\ncross section Teshi @ 0.01 ", sc_plugin3.crossSectionNonOriented(0.01))
print("\ncross section HS @ 0.01 ", sc_plugin4.crossSectionNonOriented(0.01))
# Out:
# cross section PPF @ 0.01  50.91531862863572
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4262b48eda23> in <module>
#       1 print("\ncross section PPF @ 0.01 ", sc_plugin.crossSectionNonOriented(0.01))
# ----> 2 print("\ncross section GP @ 0.01 ", sc_plugin2.crossSectionNonOriented(0.01))
#       3 print("\ncross section Teshi @ 0.01 ", sc_plugin3.crossSectionNonOriented(0.01))
#       4 print("\ncross section HS @ 0.01 ", sc_plugin4.crossSectionNonOriented(0.01))
#
# NameError: name 'sc_plugin2' is not defined

# %%
sc_plugin.sampleScatter(0.001,direction=(0,0,0.0001),repeat=10)
# Out:
# (array([0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001,
#         0.001]),
#  (array([-3.76432420e-02,  6.31059310e-02,  5.79655510e-03,  5.30869073e-03,
#          -1.16596952e-05, -6.38735863e-02,  8.49577291e-03,  7.98583267e-02,
#           2.45070502e-02,  1.91443216e-03]),
#   array([ 0.03941162,  0.05633682,  0.03223218,  0.01671257,  0.00058187,
#          -0.01719338, -0.00282056,  0.06738429,  0.00460897, -0.00249917]),
#   array([0.99851375, 0.99641548, 0.9994636 , 0.99984624, 0.99999983,
#          0.99780988, 0.99995993, 0.99452602, 0.99968903, 0.99999504])))

# %%
data_4AA_25AA = np.genfromtxt("data/theta_HSFBA_4AA_25AA")
data_4AA_50AA = np.genfromtxt("data/theta_HSFBA_4AA_50AA")
data_1AA_50AA = np.genfromtxt("data/theta_HSFBA_1AA_50AA")
data_50AA_25AA = np.genfromtxt("data/theta_HSFBA_50AA_25AA")
data_4AA_500AA = np.genfromtxt("data/theta_HSFBA_4AA_500AA")
data_50AA_500AA = np.genfromtxt("data/theta_HSFBA_50AA_500AA")

# %%
fig, ax = plt.subplots(1,1,figsize=(5,5),dpi=100)

rang = [0,20]
plt.hist(data_4AA_25AA,bins=rang[1]*5,range=rang,histtype="step",label="wl=4 Å, R=25 Å",density=True)
#plt.hist(data_4AA_50AA,bins=rang[1],range=rang, histtype="step",label="R=50AA")
plt.hist(data_4AA_500AA,bins=rang[1]*5,range=rang, histtype="step",label="wl=4 Å, R=500 Å",density=True)
plt.hist(data_50AA_25AA,bins=rang[1]*5,range=rang, histtype="step",label="wl=50 Å, R=25 Å",density=True)
plt.hist(data_50AA_500AA,bins=rang[1]*5,range=rang, histtype="step",label="wl=50 Å, R=500 Å",density=True)

plt.yscale("log")
plt.xlabel(r"$\theta$ [deg]",fontsize=13)
plt.legend(fontsize=13)
plt.tight_layout()
plt.savefig("theta_R_plots.jpg")
plt.show()
